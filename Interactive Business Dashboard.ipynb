# %% [markdown]
# # EDA Section

# %%
import pandas as pd

df = pd.read_csv("Sample - Superstore.csv", encoding="latin1")

print(df.shape)

print(df.info())

print(df.isnull().sum())

print(df.describe())
# Out:
# (9994, 21)
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Remove duplicates

df.drop_duplicates(inplace=True)

# Convert dates

df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Ship Date'] = pd.to_datetime(df['Ship Date'])

print(df.isnull().sum())
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # Total Sale And Profit

# %%
print("Total Sales =", df['Sales'].sum())

print("Total Profit =", df['Profit'].sum())
# Out:
# Total Sales = 2297200.8603
# Total Profit = 286397.0217

# %% [markdown]
# # Sales By Region

# %%
import matplotlib.pyplot as plt

sales_region = df.groupby('Region')['Sales'].sum()

sales_region.plot(kind='bar')

plt.title("Sales by Region")

plt.show()

# %% [markdown]
# # Profit By Category

# %%
profit_category = df.groupby('Category')['Profit'].sum()

profit_category.plot(kind='bar')

plt.title("Profit by Category")

plt.show()

# %% [markdown]
# # Top Customers

# %%
top_customers = df.groupby(
    'Customer Name'
)['Sales'].sum().sort_values(
    ascending=False
).head(5)

print(top_customers)
# Out:
# Customer Name
# Sean Miller      25043.050
# Tamara Chand     19052.218
# Raymond Buch     15117.339
# Tom Ashbrook     14595.620
# Adrian Barton    14473.571
# Name: Sales, dtype: float64

# %% [markdown]
# # Final Streamlit Dashboard

# %%
#  import streamlit as st
#  import pandas as pd
#  import plotly.express as px
# st.set_page_config(
#     page_title="Superstore Dashboard",
#     layout="wide"
# )

# df = pd.read_csv(
#     "Sample - Superstore.csv",
#     encoding="latin1"
# )

# # Sidebar

# st.sidebar.header("Filters")

# region = st.sidebar.multiselect(
#     "Region",
#     df["Region"].unique(),
#     default=df["Region"].unique()
# )

# category = st.sidebar.multiselect(
#     "Category",
#     df["Category"].unique(),
#     default=df["Category"].unique()
# )

# sub_category = st.sidebar.multiselect(
#     "Sub-Category",
#     df["Sub-Category"].unique(),
#     default=df["Sub-Category"].unique()
# )

# filtered_df = df[
#     (df["Region"].isin(region))
#     &
#     (df["Category"].isin(category))
#     &
#     (df["Sub-Category"].isin(sub_category))
# ]

# st.title("Global Superstore Dashboard")

# sales = filtered_df["Sales"].sum()

# profit = filtered_df["Profit"].sum()

# col1, col2 = st.columns(2)

# col1.metric("Total Sales", f"${sales:,.2f}")

# col2.metric("Total Profit", f"${profit:,.2f}")

# # Sales by Category

# sales_cat = filtered_df.groupby(
#     "Category"
# )["Sales"].sum().reset_index()

# fig1 = px.bar(
#     sales_cat,
#     x="Category",
#     y="Sales",
#     title="Sales by Category"
# )

# st.plotly_chart(fig1)

# # Profit by Category

# profit_cat = filtered_df.groupby(
#     "Category"
# )["Profit"].sum().reset_index()

# fig2 = px.bar(
#     profit_cat,
#     x="Category",
#     y="Profit",
#     title="Profit by Category"
# )

# st.plotly_chart(fig2)

# # Top Customers

# st.subheader("Top 5 Customers")

# top_customers = filtered_df.groupby(
#     "Customer Name"
# )["Sales"].sum().reset_index()

# top_customers = top_customers.sort_values(
#     by="Sales",
#     ascending=False
# ).head(5)

# st.dataframe(top_customers)

# # Region Pie Chart

# region_sales = filtered_df.groupby(
#     "Region"
# )["Sales"].sum().reset_index()

# fig3 = px.pie(
#     region_sales,
#     values="Sales",
#     names="Region",
#     title="Sales by Region"
# )

# st.plotly_chart(fig3)

# %% [markdown]
# # Final Dashboard Output
# Here is the screenshot of the completed interactive Streamlit dashboard:
#
# ![Superstore Dashboard](dashboard.png)

# %% [markdown]
# # Conlusion

# %%
# The dashboard provides an interactive view of sales and profit performance.
# Users can filter data by Region, Category, and Sub-Category.
# The dashboard highlights KPIs, top customers, and regional sales trends,
# helping businesses make data-driven decisions.
